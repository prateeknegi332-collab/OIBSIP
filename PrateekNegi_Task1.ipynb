# %% [markdown]
# Iris Flower Classification
# Oasis Infobyte Data Science Internship - Task 1
# Name: Prateek Negi

# %% [markdown]
# Objective
# The main goal of this project is to create a machine learning classification model that can guess the type of Iris flower, like Setosa, Versicolor or Virginica by looking at its measurements. This Iris flower classification model will help us understand how the physical measurements of an Iris flower can tell us what type of Iris flower it is whether it is a Setosa Iris flower a Versicolor Iris flower or a Virginica Iris flower.
#
# Dataset
# Iris Dataset (Built into scikit-learn)
# Total Samples: 150
# Technologies Used
# Python
# Pandas
# NumPy
# Matplotlib
# Seaborn
# Scikit-learn
# Jupyter Notebook

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import load_iris

# %%
from sklearn.datasets import load_iris
iris_data = load_iris()

# %%
iris_data = load_iris()

# %%
df = pd.DataFrame(data=iris_data.data, columns=iris_data.feature_names)
df['target'] = iris_data.target
display(df.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
print("\nMissing Values:")
display(df.isnull().sum())
# Out:
# Missing Values:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='target', data=df)
plt.title('Distribution of Iris Species')
plt.xlabel('Species (0: Setosa, 1: Versicolor, 2: Virginica)')
plt.ylabel('Count')
plt.show()

# %%
sns.pairplot(df, hue='target', markers=['o', 's', 'D'])
plt.suptitle('Pair Plot of Iris Features by Species', y=1.02)
plt.show()

# %%
X = df.drop('target', axis=1)
y = df['target']

print("Features (X) shape:", X.shape)
print("Target (y) shape:", y.shape)
# Out:
# Features (X) shape: (150, 4)
# Target (y) shape: (150,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

print(f"X_train shape: {X_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# X_train shape: (105, 4)
# X_test shape: (45, 4)
# y_train shape: (105,)
# y_test shape: (45,)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

dt_classifier = DecisionTreeClassifier(random_state=42)
dt_classifier.fit(X_train, y_train)

y_pred_dt = dt_classifier.predict(X_test)

print("Decision Tree Classifier Evaluation:")
print(f"Accuracy: {accuracy_score(y_test, y_pred_dt):.4f}")
print("\nClassification Report:\n", classification_report(y_test, y_pred_dt))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred_dt))
# Out:
# Decision Tree Classifier Evaluation:
# Accuracy: 0.9333
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       1.00      0.80      0.89        15
#            2       0.83      1.00      0.91        15
#
#     accuracy                           0.93        45
#    macro avg       0.94      0.93      0.93        45
# weighted avg       0.94      0.93      0.93        45
#
#
# Confusion Matrix:
#  [[15  0  0]
#  [ 0 12  3]
#  [ 0  0 15]]

# %%
from sklearn.neighbors import KNeighborsClassifier

knn_classifier = KNeighborsClassifier(n_neighbors=5)
knn_classifier.fit(X_train, y_train)

y_pred_knn = knn_classifier.predict(X_test)

print("K-Nearest Neighbors Classifier Evaluation:")
print(f"Accuracy: {accuracy_score(y_test, y_pred_knn):.4f}")
print("\nClassification Report:\n", classification_report(y_test, y_pred_knn))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred_knn))
# Out:
# K-Nearest Neighbors Classifier Evaluation:
# Accuracy: 0.9778
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       0.94      1.00      0.97        15
#            2       1.00      0.93      0.97        15
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45
#
#
# Confusion Matrix:
#  [[15  0  0]
#  [ 0 15  0]
#  [ 0  1 14]]
